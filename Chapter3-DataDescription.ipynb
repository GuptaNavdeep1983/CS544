# %% [markdown]
# <a href="https://colab.research.google.com/github/GuptaNavdeep1983/CS544/blob/main/Chapter3-DataDescription.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Discrete data
#
# #Continuous data

# %%
str(discoveries)
str(precip)
str(rivers)
# Out:
#  Time-Series [1:100] from 1860 to 1959: 5 3 0 2 0 3 2 3 6 1 ...

# %% [markdown]
# #Strip Chart (Also known as Dot plots)

# %%
stripchart(precip, xlab = "rainfall")
stripchart(rivers, method = "jitter")
stripchart(discoveries, method="stack")
# Out:
# plot without title
# plot without title
# plot without title

# %%
hist(precip)
hist(precip, freq = FALSE)
# Out:
# Plot with title “Histogram of precip”
# Plot with title “Histogram of precip”
